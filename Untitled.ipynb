# %%
# %matplotlib inline

# %%
# %run analysis_csv.py 3.log.csv
# Out:
# data_size(Byte)
# talk_length
# comm_freq(Hz)
# run_time(sec)
# lstn_length

# %%
import statistics
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-5fbf3e91e55e> in <module>()
# ----> 1 import statistics
#
# ImportError: No module named statistics

# %%
import scipy
