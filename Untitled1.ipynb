# %%
# %matplotlib inline

# %%
import sys
print(sys.path)
# Out:
# ['', '/opt/ros/lunar/lib/python2.7/dist-packages', '/usr/lib/python35.zip', '/usr/lib/python3.5', '/usr/lib/python3.5/plat-x86_64-linux-gnu', '/usr/lib/python3.5/lib-dynload', '/home/yt113/.local/lib/python3.5/site-packages', '/usr/local/lib/python3.5/dist-packages', '/usr/lib/python3/dist-packages', '/home/yt113/.local/lib/python3.5/site-packages/IPython/extensions', '/home/yt113/.ipython']

# %%
# %run analysis_csv.py 5.log.csv delay
# Out:
# (2, 2)
